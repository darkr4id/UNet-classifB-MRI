# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Import Libraries</h3> <a id=1.1></a> <br>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import glob

import time
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
from IPython.display import Image
from skimage import io

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.layers.experimental import preprocessing
from keras.utils.vis_utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
import cv2
from sklearn.preprocessing import StandardScaler, normalize
from IPython.display import display

# %%
img_data = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
img_data.head()
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0

# %%
img_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
img_data.shape
# Out:
# (110, 18)

# %%
data_path = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            mask_path = sub_dir_path + '/' + filename
            data_path.extend([dir_name, mask_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
filenames = data_path[::2]
masks = data_path[1::2]

# %%
df = pd.DataFrame(data={"patient_id": filenames,"img_path": masks})
df
# Out:
#                  patient_id                                           img_path
# 0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                     ...                                                ...
# 7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [7858 rows x 2 columns]

# %%
original_img     = df[~df['img_path'].str.contains("mask")]
mask_img = df[df['img_path'].str.contains("mask")]

# %%
original_img,mask_img
# Out:
# (                 patient_id                                           img_path
#  0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  5     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7849  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7850  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7852  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns],
#                   patient_id                                           img_path
#  1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  8     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  9     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  11    TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7846  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7851  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns])

# %%
imgs = sorted(original_img["img_path"].values, key=lambda x : int(x[89:-4]))
masks = sorted(mask_img["img_path"].values, key=lambda x : int(x[89:-9]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Image path:", imgs[idx], "\nMask path:", masks[idx])
# Out:
# Image path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_42.tif
# Mask path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_A60K_20040224/TCGA_FG_A60K_20040224_42_mask.tif

# %%
mri_df = pd.DataFrame({"patient_id": original_img.patient_id.values,"img_path": imgs,
                           'mask_path':masks})
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [3929 rows x 3 columns]

# %%
def get_diagnosis(img_path):
    value = np.max(cv2.imread(img_path))
    if value > 0 : 
        return 1
    else:
        return 0

# %%
mri_df.head()
# Out:
#               patient_id                                           img_path  \
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
mri_df['mask'] = mri_df['mask_path'].apply(lambda x: get_diagnosis(x))

mri_df['mask_path'] = mri_df['mask_path'].apply(lambda x: str(x))
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# ...                                                 ...   ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
# [3929 rows x 4 columns]

# %%
mri_df.drop(columns=['patient_id'],inplace=True)

# %%
mri_train, mri_test = train_test_split(mri_df,test_size = 0.1)
mri_train, mri_val = train_test_split(mri_train,test_size = 0.2)

print('Training data shape is {0}'.format(mri_train.values.shape))
print('Test data shape is {0}'.format(mri_test.values.shape))
mri_train.sample(n=5)
# Out:
# Training data shape is (2828, 3)
# Test data shape is (393, 3)
#                                                img_path  \
# 2592  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 938   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2447  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2308  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 703   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 2592  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 938   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2447  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2308  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 703   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">EDA</h3> <a id=2></a> <br>
#
# Check Balancing in Data

# %%
mri_df['mask'].value_counts().plot(kind='bar',color=['g','r'],
                title='Count of Tumour vs No Tumour')
# Out:
# <AxesSubplot:title={'center':'Count of Tumour vs No Tumour'}>

# %%
mri_df['mask'].value_counts()
# Out:
# 0    2556
# 1    1373
# Name: mask, dtype: int64

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Image Visualization</h3> <a id=2></a> <br>
#
# Visualising the Brain MRI with Tumour

# %%
count = 0
i = 0
fig,axs = plt.subplots(3,3, figsize=(20,20))
for mask in mri_df['mask']:
    if (mask==1):
        img = io.imread(mri_df.img_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(mri_df.mask_path[i])
        axs[count][1].title.set_text("Mask =" + str(mri_df['mask'][i]))
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (255,0,0)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask =" + str(mri_df['mask'][i]))
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==3):
        break
        
fig.tight_layout()

# %%
# Basic visualizations: Visualize the images (MRI and Mask) in the dataset separately 

fig, axs = plt.subplots(4,2, figsize=(13,26))
count = 0
for x in range(4):
  i = random.randint(0, len(mri_df)) 
  axs[count][0].title.set_text("Brain MRI") 
  axs[count][0].imshow(cv2.imread(mri_df.img_path[i])) 
  axs[count][1].title.set_text("Mask - " + str(mri_df['mask'][i])) 
  axs[count][1].imshow(cv2.imread(mri_df.mask_path[i])) 
  count += 1

fig.tight_layout()

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Data Generator</h3> <a id=3></a> <br>
# ### Reference : **[UNet](https://github.com/zhixuhao/unet)**

# %%
from keras_preprocessing.image import ImageDataGenerator

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "img_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

# %%
def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(mri_train, 32,
                                train_generator_args,
                                target_size=(256, 256))
    
val_gen = train_generator(mri_val, 32,
                                dict(),
                                target_size=(256, 256))

# %% [markdown]
# # <h3 style="color:#FF0000;background-color:white;font-size:25px">Build UNet Model</h3> <a id=4></a> <br>
#
# <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Architecture</h3> <a id=4.1></a>
#
# <center><img src= "https://miro.medium.com/max/1200/1*f7YOaE4TWubwaFF7Z1fzNw.png" alt ="UNet" style='width:800px;'></center>

# %% [markdown]
# UNet is named after the shape of it's architecture (U - shaped). UNet model is used to solve Image Segmentation problems especially in Medical related problems.
#
# The input layer has 572x572x1 dimension in the above architecture. The 1 column dimension specifies the input is b/w image. If the input dimension was 572x572x3 , the input image is rgb coloured image.
# After the input layer,we can divide this UNet architecture into 4 parts
# * Encoder Part (Contracting path)
# * Upsampling2D
# * Decoder part (Expanding Path)
# * Skip Connection (Residual connection)
#
#
# Briefly into the Details of these parts: <br>
# **Encoder Part**
# The initial half of the U-shaped architecture is the Contracting path(Encoder part). As the name Contracting path denotes, the dimension of the input image keeps reducing as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=64 followed by Maxpool2D layer (reduces size divided by 2). Now again 2 - Conv2D layers (128 filters) and 1 Maxpooling2D , 2 - Conv2D layers (256 filters) and 1 Maxpooling2D completely contracts the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Upsampling2D**
# The Upsampling2D layer upsamples the layer output dimension by duplicating the row values twice.The concatenation of the upsampling2D and contracting path happens here leading into the Expanding path.
# The Upsampling layer is present after 2 conv2D layers in Decoder part, similar to presence of  Maxpooling as in Encoder part.
#
# **Decoder Path**
# The second half of the U-shaped architecture is the Expanding path(Decoder part). As the name Expanding path denotes, the dimension of the image keeps expanding as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=512 followed by Upsampling2D layer (duplicates size divided by 2). Now again 2 - Conv2D layers (256 filters) and 1 Upsampling2D ,2 - Conv2D layers (128 filters) and 1 Upsampling2D, 2 - Conv2D layers (64 filters) completely expands the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Skip Connection (Residual connection)**
# The Skip Connection (Residual connection) alias the identity mapping is present after each of the 2 Conv2D layers in Encoder to the corresponding same shaped dimension layer in the Decoder part . In the above architecture the copy and crop does residual connection task.The Concatenate layer does the work of adding those two layers. This skip connection doesnot harm the model in any way even in worst case but definitely benificial to the output in the model.
#
# Finally the decoder part ends with the Output Segmentation map with filters 2. This layer is again passed through a Conv2D with Sigmoid activation and filters 1. The output classifies each pixel if tumour is present or not in it.
#
# ### Reference : [UNet](https://github.com/zhixuhao/unet)

# %%
def unet(pretrained_weights = None,input_size = (256,256,3)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv1)
    bn_1 = BatchNormalization(axis=3)(conv1)
    act_1 = Activation('relu')(bn_1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(act_1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    bn_2 = BatchNormalization(axis=3)(conv2)
    act_2 = Activation('relu')(bn_2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(act_2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv3)
    bn_3 = BatchNormalization(axis=3)(conv3)
    act_3 = Activation('relu')(bn_3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(act_3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv4)
    bn_4 = BatchNormalization(axis=3)(conv4)
    act_4 = Activation('relu')(bn_4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(act_4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv5)
    bn_5 = BatchNormalization(axis=3)(conv5)
    act_5 = Activation('relu')(bn_5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv6)
    bn_6 = BatchNormalization(axis=3)(conv6)
    act_6 = Activation('relu')(bn_6)
    
    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv7)
    bn_7 = BatchNormalization(axis=3)(conv7)
    act_7 = Activation('relu')(bn_7)

    
    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv8)
    bn_8 = BatchNormalization(axis=3)(conv8)
    act_8 = Activation('relu')(bn_8)
    
    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv9)
    bn_9 = BatchNormalization(axis=3)(conv9)
    act_9 = Activation('relu')(bn_9)
    
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(act_9)

    model = model = Model(inputs=[inputs] , outputs = [conv10])    
    return model

# %%
model = unet()
model.summary()
# Out:
# 2022-10-20 12:15:44.788518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:44.880404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:44.881266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:44.882694: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-20 12:15:44.883092: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:44.883870: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:44.884528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:47.004773: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:47.005580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:47.006283: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-20 12:15:47.006909: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 256, 2)  8           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 2)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 1)  3           activation_8[0][0]
# ==================================================================================================
# Total params: 31,044,365
# Trainable params: 31,038,601
# Non-trainable params: 5,764
# __________________________________________________________________________________________________

# %% [markdown]
# <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Model architecture</h3> <a id=5></a>

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Callbacks</h3> <a id=5.2></a> <br>
#
# The Callbacks used are
# * Learning Rate reduction
# * Early Stopping
# * Model Checkpoint

# %%
lr_reduction = ReduceLROnPlateau(monitor='val_iou',patience=8, verbose=1,
                                 factor=0.4, min_lr=0.0001)

early_stop = EarlyStopping(monitor='val_iou', min_delta=0.00001, patience=6, 
                           mode='auto', restore_best_weights=True)

model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', verbose=1,
                                   save_best_only=True)

# %%
EPOCH = 100
learning_rate = 1e-4

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Performance Metrics</h3> <a id=5.2></a>

# %%
smooth =100
def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Model Fit</h3> <a id=5.3></a>

# %%
model.compile(optimizer=Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-3/32, amsgrad=False), 
              loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/3159380141.py in <module>
# ----> 1 model.compile(optimizer=Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-3/32, amsgrad=False),
#       2               loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])
#
# NameError: name 'model' is not defined

# %%
history = model.fit(train_gen,steps_per_epoch=len(mri_train) / 32,
                    epochs=EPOCH ,validation_data=val_gen,validation_steps=len(mri_val) / 32,
                    callbacks=[model_checkpoint])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# 2022-10-20 12:15:52.663697: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-10-20 12:15:55.421931: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 2022-10-20 12:16:09.984143: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-20 12:16:10.065146: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-20 12:16:10.221021: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 89/88 [==============================] - ETA: 0s - loss: 0.9584 - binary_accuracy: 0.8958 - iou: 0.0213 - dice_coef: 0.0416Found 708 validated image filenames.
# Found 708 validated image filenames.
# 88/88 [==============================] - 133s 1s/step - loss: 0.9584 - binary_accuracy: 0.8958 - iou: 0.0213 - dice_coef: 0.0416 - val_loss: 0.9696 - val_binary_accuracy: 0.2799 - val_iou: 0.0150 - val_dice_coef: 0.0294
#
# Epoch 00001: val_loss improved from inf to 0.96956, saving model to unet_membrane.hdf5
# Epoch 2/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.9507 - binary_accuracy: 0.9364 - iou: 0.0255 - dice_coef: 0.0495 - val_loss: 0.9472 - val_binary_accuracy: 0.9236 - val_iou: 0.0263 - val_dice_coef: 0.0508
#
# Epoch 00002: val_loss improved from 0.96956 to 0.94721, saving model to unet_membrane.hdf5
# Epoch 3/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.9425 - binary_accuracy: 0.9511 - iou: 0.0298 - dice_coef: 0.0576 - val_loss: 0.9417 - val_binary_accuracy: 0.9730 - val_iou: 0.0300 - val_dice_coef: 0.0578
#
# Epoch 00003: val_loss improved from 0.94721 to 0.94165, saving model to unet_membrane.hdf5
# Epoch 4/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.9292 - binary_accuracy: 0.9591 - iou: 0.0368 - dice_coef: 0.0706 - val_loss: 0.9009 - val_binary_accuracy: 0.9538 - val_iou: 0.0507 - val_dice_coef: 0.0954
#
# Epoch 00004: val_loss improved from 0.94165 to 0.90089, saving model to unet_membrane.hdf5
# Epoch 5/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9085 - binary_accuracy: 0.9717 - iou: 0.0485 - dice_coef: 0.0916 - val_loss: 0.8874 - val_binary_accuracy: 0.9793 - val_iou: 0.0580 - val_dice_coef: 0.1085
#
# Epoch 00005: val_loss improved from 0.90089 to 0.88738, saving model to unet_membrane.hdf5
# Epoch 6/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.8801 - binary_accuracy: 0.9799 - iou: 0.0648 - dice_coef: 0.1202 - val_loss: 0.8353 - val_binary_accuracy: 0.9377 - val_iou: 0.0890 - val_dice_coef: 0.1615
#
# Epoch 00006: val_loss improved from 0.88738 to 0.83529, saving model to unet_membrane.hdf5
# Epoch 7/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.8344 - binary_accuracy: 0.9784 - iou: 0.0914 - dice_coef: 0.1656 - val_loss: 0.7628 - val_binary_accuracy: 0.9552 - val_iou: 0.1376 - val_dice_coef: 0.2386
#
# Epoch 00007: val_loss improved from 0.83529 to 0.76280, saving model to unet_membrane.hdf5
# Epoch 8/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.7654 - binary_accuracy: 0.9864 - iou: 0.1345 - dice_coef: 0.2341 - val_loss: 0.6970 - val_binary_accuracy: 0.9930 - val_iou: 0.1850 - val_dice_coef: 0.3073
#
# Epoch 00008: val_loss improved from 0.76280 to 0.69698, saving model to unet_membrane.hdf5
# Epoch 9/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.6782 - binary_accuracy: 0.9899 - iou: 0.1956 - dice_coef: 0.3212 - val_loss: 0.6295 - val_binary_accuracy: 0.9940 - val_iou: 0.2250 - val_dice_coef: 0.3580
#
# Epoch 00009: val_loss improved from 0.69698 to 0.62954, saving model to unet_membrane.hdf5
# Epoch 10/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.5840 - binary_accuracy: 0.9916 - iou: 0.2684 - dice_coef: 0.4164 - val_loss: 0.5524 - val_binary_accuracy: 0.9926 - val_iou: 0.3116 - val_dice_coef: 0.4607
#
# Epoch 00010: val_loss improved from 0.62954 to 0.55243, saving model to unet_membrane.hdf5
# Epoch 11/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.5011 - binary_accuracy: 0.9928 - iou: 0.3389 - dice_coef: 0.4993 - val_loss: 0.4892 - val_binary_accuracy: 0.9940 - val_iou: 0.3433 - val_dice_coef: 0.4927
#
# Epoch 00011: val_loss improved from 0.55243 to 0.48925, saving model to unet_membrane.hdf5
# Epoch 12/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.4637 - binary_accuracy: 0.9931 - iou: 0.3727 - dice_coef: 0.5359 - val_loss: 0.9147 - val_binary_accuracy: 0.9935 - val_iou: 0.0449 - val_dice_coef: 0.0849
#
# Epoch 00012: val_loss did not improve from 0.48925
# Epoch 13/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.4124 - binary_accuracy: 0.9940 - iou: 0.4216 - dice_coef: 0.5862 - val_loss: 0.7633 - val_binary_accuracy: 0.9945 - val_iou: 0.1352 - val_dice_coef: 0.2344
#
# Epoch 00013: val_loss did not improve from 0.48925
# Epoch 14/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3807 - binary_accuracy: 0.9944 - iou: 0.4561 - dice_coef: 0.6163 - val_loss: 0.9178 - val_binary_accuracy: 0.9928 - val_iou: 0.0420 - val_dice_coef: 0.0795
#
# Epoch 00014: val_loss did not improve from 0.48925
# Epoch 15/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.3736 - binary_accuracy: 0.9946 - iou: 0.4672 - dice_coef: 0.6275 - val_loss: 0.9095 - val_binary_accuracy: 0.9941 - val_iou: 0.0472 - val_dice_coef: 0.0895
#
# Epoch 00015: val_loss did not improve from 0.48925
# Epoch 16/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3235 - binary_accuracy: 0.9953 - iou: 0.5195 - dice_coef: 0.6771 - val_loss: 0.7970 - val_binary_accuracy: 0.9958 - val_iou: 0.1149 - val_dice_coef: 0.2036
#
# Epoch 00016: val_loss did not improve from 0.48925
# Epoch 17/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2989 - binary_accuracy: 0.9956 - iou: 0.5473 - dice_coef: 0.7009 - val_loss: 0.8699 - val_binary_accuracy: 0.9951 - val_iou: 0.0678 - val_dice_coef: 0.1253
#
# Epoch 00017: val_loss did not improve from 0.48925
# Epoch 18/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2994 - binary_accuracy: 0.9954 - iou: 0.5428 - dice_coef: 0.6985 - val_loss: 0.9339 - val_binary_accuracy: 0.9948 - val_iou: 0.0345 - val_dice_coef: 0.0661
#
# Epoch 00018: val_loss did not improve from 0.48925
# Epoch 19/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2864 - binary_accuracy: 0.9956 - iou: 0.5631 - dice_coef: 0.7142 - val_loss: 0.3660 - val_binary_accuracy: 0.9954 - val_iou: 0.4539 - val_dice_coef: 0.6116
#
# Epoch 00019: val_loss improved from 0.48925 to 0.36597, saving model to unet_membrane.hdf5
# Epoch 20/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2786 - binary_accuracy: 0.9957 - iou: 0.5716 - dice_coef: 0.7220 - val_loss: 0.3936 - val_binary_accuracy: 0.9950 - val_iou: 0.4568 - val_dice_coef: 0.6138
#
# Epoch 00020: val_loss did not improve from 0.36597
# Epoch 21/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2662 - binary_accuracy: 0.9959 - iou: 0.5886 - dice_coef: 0.7340 - val_loss: 0.2704 - val_binary_accuracy: 0.9962 - val_iou: 0.5895 - val_dice_coef: 0.7348
#
# Epoch 00021: val_loss improved from 0.36597 to 0.27036, saving model to unet_membrane.hdf5
# Epoch 22/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2532 - binary_accuracy: 0.9962 - iou: 0.6047 - dice_coef: 0.7471 - val_loss: 0.6074 - val_binary_accuracy: 0.9933 - val_iou: 0.2419 - val_dice_coef: 0.3785
#
# Epoch 00022: val_loss did not improve from 0.27036
# Epoch 23/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2637 - binary_accuracy: 0.9958 - iou: 0.5879 - dice_coef: 0.7355 - val_loss: 0.3291 - val_binary_accuracy: 0.9958 - val_iou: 0.5071 - val_dice_coef: 0.6557
#
# Epoch 00023: val_loss did not improve from 0.27036
# Epoch 24/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2440 - binary_accuracy: 0.9962 - iou: 0.6154 - dice_coef: 0.7566 - val_loss: 0.3096 - val_binary_accuracy: 0.9949 - val_iou: 0.5167 - val_dice_coef: 0.6675
#
# Epoch 00024: val_loss did not improve from 0.27036
# Epoch 25/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2374 - binary_accuracy: 0.9963 - iou: 0.6207 - dice_coef: 0.7611 - val_loss: 0.2478 - val_binary_accuracy: 0.9959 - val_iou: 0.5970 - val_dice_coef: 0.7375
#
# Epoch 00025: val_loss improved from 0.27036 to 0.24782, saving model to unet_membrane.hdf5
# Epoch 26/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2437 - binary_accuracy: 0.9961 - iou: 0.6158 - dice_coef: 0.7564 - val_loss: 0.5133 - val_binary_accuracy: 0.9964 - val_iou: 0.3136 - val_dice_coef: 0.4694
#
# Epoch 00026: val_loss did not improve from 0.24782
# Epoch 27/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2324 - binary_accuracy: 0.9963 - iou: 0.6291 - dice_coef: 0.7667 - val_loss: 0.2580 - val_binary_accuracy: 0.9962 - val_iou: 0.5902 - val_dice_coef: 0.7258
#
# Epoch 00027: val_loss did not improve from 0.24782
# Epoch 28/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2352 - binary_accuracy: 0.9964 - iou: 0.6273 - dice_coef: 0.7640 - val_loss: 0.2170 - val_binary_accuracy: 0.9972 - val_iou: 0.6321 - val_dice_coef: 0.7598
#
# Epoch 00028: val_loss improved from 0.24782 to 0.21700, saving model to unet_membrane.hdf5
# Epoch 29/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2064 - binary_accuracy: 0.9967 - iou: 0.6652 - dice_coef: 0.7938 - val_loss: 0.2683 - val_binary_accuracy: 0.9968 - val_iou: 0.5674 - val_dice_coef: 0.7095
#
# Epoch 00029: val_loss did not improve from 0.21700
# Epoch 30/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2089 - binary_accuracy: 0.9967 - iou: 0.6618 - dice_coef: 0.7913 - val_loss: 0.4072 - val_binary_accuracy: 0.9948 - val_iou: 0.4356 - val_dice_coef: 0.5954
#
# Epoch 00030: val_loss did not improve from 0.21700
# Epoch 31/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2101 - binary_accuracy: 0.9966 - iou: 0.6583 - dice_coef: 0.7901 - val_loss: 0.2633 - val_binary_accuracy: 0.9947 - val_iou: 0.6030 - val_dice_coef: 0.7441
#
# Epoch 00031: val_loss did not improve from 0.21700
# Epoch 32/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2073 - binary_accuracy: 0.9967 - iou: 0.6632 - dice_coef: 0.7929 - val_loss: 0.2614 - val_binary_accuracy: 0.9961 - val_iou: 0.5935 - val_dice_coef: 0.7402
#
# Epoch 00032: val_loss did not improve from 0.21700
# Epoch 33/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2081 - binary_accuracy: 0.9966 - iou: 0.6621 - dice_coef: 0.7911 - val_loss: 0.2502 - val_binary_accuracy: 0.9966 - val_iou: 0.6052 - val_dice_coef: 0.7465
#
# Epoch 00033: val_loss did not improve from 0.21700
# Epoch 34/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1929 - binary_accuracy: 0.9970 - iou: 0.6851 - dice_coef: 0.8074 - val_loss: 0.2256 - val_binary_accuracy: 0.9968 - val_iou: 0.6344 - val_dice_coef: 0.7728
#
# Epoch 00034: val_loss did not improve from 0.21700
# Epoch 35/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1971 - binary_accuracy: 0.9968 - iou: 0.6775 - dice_coef: 0.8035 - val_loss: 0.1949 - val_binary_accuracy: 0.9973 - val_iou: 0.6881 - val_dice_coef: 0.8073
#
# Epoch 00035: val_loss improved from 0.21700 to 0.19489, saving model to unet_membrane.hdf5
# Epoch 36/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1948 - binary_accuracy: 0.9968 - iou: 0.6784 - dice_coef: 0.8013 - val_loss: 0.4915 - val_binary_accuracy: 0.9937 - val_iou: 0.3706 - val_dice_coef: 0.5228
#
# Epoch 00036: val_loss did not improve from 0.19489
# Epoch 37/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2189 - binary_accuracy: 0.9964 - iou: 0.6514 - dice_coef: 0.7816 - val_loss: 0.2139 - val_binary_accuracy: 0.9963 - val_iou: 0.6380 - val_dice_coef: 0.7701
#
# Epoch 00037: val_loss did not improve from 0.19489
# Epoch 38/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1897 - binary_accuracy: 0.9968 - iou: 0.6841 - dice_coef: 0.8077 - val_loss: 0.3007 - val_binary_accuracy: 0.9955 - val_iou: 0.5556 - val_dice_coef: 0.7073
#
# Epoch 00038: val_loss did not improve from 0.19489
# Epoch 39/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2148 - binary_accuracy: 0.9964 - iou: 0.6532 - dice_coef: 0.7841 - val_loss: 0.2544 - val_binary_accuracy: 0.9968 - val_iou: 0.6150 - val_dice_coef: 0.7518
#
# Epoch 00039: val_loss did not improve from 0.19489
# Epoch 40/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1851 - binary_accuracy: 0.9969 - iou: 0.6960 - dice_coef: 0.8154 - val_loss: 0.1713 - val_binary_accuracy: 0.9972 - val_iou: 0.7077 - val_dice_coef: 0.8258
#
# Epoch 00040: val_loss improved from 0.19489 to 0.17126, saving model to unet_membrane.hdf5
# Epoch 41/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1712 - binary_accuracy: 0.9971 - iou: 0.7155 - dice_coef: 0.8292 - val_loss: 0.1797 - val_binary_accuracy: 0.9970 - val_iou: 0.6911 - val_dice_coef: 0.8065
#
# Epoch 00041: val_loss did not improve from 0.17126
# Epoch 42/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1743 - binary_accuracy: 0.9971 - iou: 0.7087 - dice_coef: 0.8259 - val_loss: 0.1765 - val_binary_accuracy: 0.9974 - val_iou: 0.7034 - val_dice_coef: 0.8226
#
# Epoch 00042: val_loss did not improve from 0.17126
# Epoch 43/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1923 - binary_accuracy: 0.9967 - iou: 0.6827 - dice_coef: 0.8079 - val_loss: 0.1846 - val_binary_accuracy: 0.9968 - val_iou: 0.6835 - val_dice_coef: 0.8015
#
# Epoch 00043: val_loss did not improve from 0.17126
# Epoch 44/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1708 - binary_accuracy: 0.9971 - iou: 0.7144 - dice_coef: 0.8296 - val_loss: 0.2204 - val_binary_accuracy: 0.9970 - val_iou: 0.6609 - val_dice_coef: 0.7826
#
# Epoch 00044: val_loss did not improve from 0.17126
# Epoch 45/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1623 - binary_accuracy: 0.9973 - iou: 0.7260 - dice_coef: 0.8376 - val_loss: 0.1885 - val_binary_accuracy: 0.9971 - val_iou: 0.6917 - val_dice_coef: 0.8140
#
# Epoch 00045: val_loss did not improve from 0.17126
# Epoch 46/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1659 - binary_accuracy: 0.9973 - iou: 0.7203 - dice_coef: 0.8338 - val_loss: 0.1863 - val_binary_accuracy: 0.9969 - val_iou: 0.6768 - val_dice_coef: 0.7944
#
# Epoch 00046: val_loss did not improve from 0.17126
# Epoch 47/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1643 - binary_accuracy: 0.9972 - iou: 0.7232 - dice_coef: 0.8355 - val_loss: 0.1628 - val_binary_accuracy: 0.9973 - val_iou: 0.7225 - val_dice_coef: 0.8370
#
# Epoch 00047: val_loss improved from 0.17126 to 0.16284, saving model to unet_membrane.hdf5
# Epoch 48/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1607 - binary_accuracy: 0.9973 - iou: 0.7293 - dice_coef: 0.8388 - val_loss: 0.1559 - val_binary_accuracy: 0.9973 - val_iou: 0.7154 - val_dice_coef: 0.8269
#
# Epoch 00048: val_loss improved from 0.16284 to 0.15589, saving model to unet_membrane.hdf5
# Epoch 49/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1641 - binary_accuracy: 0.9972 - iou: 0.7229 - dice_coef: 0.8356 - val_loss: 0.1693 - val_binary_accuracy: 0.9970 - val_iou: 0.6974 - val_dice_coef: 0.8091
#
# Epoch 00049: val_loss did not improve from 0.15589
# Epoch 50/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1524 - binary_accuracy: 0.9974 - iou: 0.7392 - dice_coef: 0.8471 - val_loss: 0.1563 - val_binary_accuracy: 0.9974 - val_iou: 0.7102 - val_dice_coef: 0.8133
#
# Epoch 00050: val_loss did not improve from 0.15589
# Epoch 51/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1512 - binary_accuracy: 0.9973 - iou: 0.7419 - dice_coef: 0.8483 - val_loss: 0.1590 - val_binary_accuracy: 0.9974 - val_iou: 0.7333 - val_dice_coef: 0.8437
#
# Epoch 00051: val_loss did not improve from 0.15589
# Epoch 52/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1410 - binary_accuracy: 0.9976 - iou: 0.7570 - dice_coef: 0.8594 - val_loss: 0.1767 - val_binary_accuracy: 0.9971 - val_iou: 0.6995 - val_dice_coef: 0.8209
#
# Epoch 00052: val_loss did not improve from 0.15589
# Epoch 53/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1538 - binary_accuracy: 0.9974 - iou: 0.7420 - dice_coef: 0.8465 - val_loss: 0.1562 - val_binary_accuracy: 0.9975 - val_iou: 0.7159 - val_dice_coef: 0.8208
#
# Epoch 00053: val_loss did not improve from 0.15589
# Epoch 54/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1496 - binary_accuracy: 0.9974 - iou: 0.7446 - dice_coef: 0.8502 - val_loss: 0.1552 - val_binary_accuracy: 0.9976 - val_iou: 0.7388 - val_dice_coef: 0.8463
#
# Epoch 00054: val_loss improved from 0.15589 to 0.15521, saving model to unet_membrane.hdf5
# Epoch 55/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1341 - binary_accuracy: 0.9976 - iou: 0.7681 - dice_coef: 0.8659 - val_loss: 0.1560 - val_binary_accuracy: 0.9976 - val_iou: 0.7299 - val_dice_coef: 0.8404
#
# Epoch 00055: val_loss did not improve from 0.15521
# Epoch 56/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1531 - binary_accuracy: 0.9973 - iou: 0.7413 - dice_coef: 0.8473 - val_loss: 0.1441 - val_binary_accuracy: 0.9974 - val_iou: 0.7551 - val_dice_coef: 0.8583
#
# Epoch 00056: val_loss improved from 0.15521 to 0.14413, saving model to unet_membrane.hdf5
# Epoch 57/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1479 - binary_accuracy: 0.9974 - iou: 0.7482 - dice_coef: 0.8527 - val_loss: 0.2229 - val_binary_accuracy: 0.9957 - val_iou: 0.6342 - val_dice_coef: 0.7718
#
# Epoch 00057: val_loss did not improve from 0.14413
# Epoch 58/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1700 - binary_accuracy: 0.9969 - iou: 0.7195 - dice_coef: 0.8307 - val_loss: 0.1672 - val_binary_accuracy: 0.9973 - val_iou: 0.7148 - val_dice_coef: 0.8243
#
# Epoch 00058: val_loss did not improve from 0.14413
# Epoch 59/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9467 - binary_accuracy: 0.9779 - iou: 0.0293 - dice_coef: 0.0530 - val_loss: 0.2732 - val_binary_accuracy: 0.9951 - val_iou: 0.5863 - val_dice_coef: 0.7313
#
# Epoch 00059: val_loss did not improve from 0.14413
# Epoch 60/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9368 - binary_accuracy: 0.9554 - iou: 0.0335 - dice_coef: 0.0627 - val_loss: 0.6187 - val_binary_accuracy: 0.9717 - val_iou: 0.2462 - val_dice_coef: 0.3867
#
# Epoch 00060: val_loss did not improve from 0.14413
# Epoch 61/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1824 - binary_accuracy: 0.9953 - iou: 0.7117 - dice_coef: 0.8181 - val_loss: 0.1925 - val_binary_accuracy: 0.9966 - val_iou: 0.6927 - val_dice_coef: 0.8138
#
# Epoch 00061: val_loss did not improve from 0.14413
# Epoch 62/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1383 - binary_accuracy: 0.9973 - iou: 0.7622 - dice_coef: 0.8611 - val_loss: 0.1591 - val_binary_accuracy: 0.9972 - val_iou: 0.7397 - val_dice_coef: 0.8460
#
# Epoch 00062: val_loss did not improve from 0.14413
# Epoch 63/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9479 - binary_accuracy: 0.9797 - iou: 0.0285 - dice_coef: 0.0518 - val_loss: 0.2543 - val_binary_accuracy: 0.9944 - val_iou: 0.5864 - val_dice_coef: 0.7321
#
# Epoch 00063: val_loss did not improve from 0.14413
# Epoch 64/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1484 - binary_accuracy: 0.9971 - iou: 0.7472 - dice_coef: 0.8515 - val_loss: 0.1491 - val_binary_accuracy: 0.9974 - val_iou: 0.7500 - val_dice_coef: 0.8549
#
# Epoch 00064: val_loss did not improve from 0.14413
# Epoch 65/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1406 - binary_accuracy: 0.9974 - iou: 0.7607 - dice_coef: 0.8586 - val_loss: 0.1560 - val_binary_accuracy: 0.9974 - val_iou: 0.7329 - val_dice_coef: 0.8385
#
# Epoch 00065: val_loss did not improve from 0.14413
# Epoch 66/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1412 - binary_accuracy: 0.9973 - iou: 0.7562 - dice_coef: 0.8584 - val_loss: 0.1672 - val_binary_accuracy: 0.9971 - val_iou: 0.7266 - val_dice_coef: 0.8383
#
# Epoch 00066: val_loss did not improve from 0.14413
# Epoch 67/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1303 - binary_accuracy: 0.9975 - iou: 0.7719 - dice_coef: 0.8648 - val_loss: 0.1579 - val_binary_accuracy: 0.9973 - val_iou: 0.7110 - val_dice_coef: 0.8162
#
# Epoch 00067: val_loss did not improve from 0.14413
# Epoch 68/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1237 - binary_accuracy: 0.9977 - iou: 0.7863 - dice_coef: 0.8766 - val_loss: 0.1276 - val_binary_accuracy: 0.9976 - val_iou: 0.7721 - val_dice_coef: 0.8701
#
# Epoch 00068: val_loss improved from 0.14413 to 0.12764, saving model to unet_membrane.hdf5
# Epoch 69/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1214 - binary_accuracy: 0.9977 - iou: 0.7879 - dice_coef: 0.8789 - val_loss: 0.1830 - val_binary_accuracy: 0.9970 - val_iou: 0.7051 - val_dice_coef: 0.8214
#
# Epoch 00069: val_loss did not improve from 0.12764
# Epoch 70/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1480 - binary_accuracy: 0.9971 - iou: 0.7495 - dice_coef: 0.8525 - val_loss: 0.1384 - val_binary_accuracy: 0.9976 - val_iou: 0.7663 - val_dice_coef: 0.8650
#
# Epoch 00070: val_loss did not improve from 0.12764
# Epoch 71/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1291 - binary_accuracy: 0.9975 - iou: 0.7775 - dice_coef: 0.8714 - val_loss: 0.1276 - val_binary_accuracy: 0.9976 - val_iou: 0.7770 - val_dice_coef: 0.8735
#
# Epoch 00071: val_loss improved from 0.12764 to 0.12759, saving model to unet_membrane.hdf5
# Epoch 72/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1851 - binary_accuracy: 0.9964 - iou: 0.6987 - dice_coef: 0.8157 - val_loss: 0.2682 - val_binary_accuracy: 0.9961 - val_iou: 0.5970 - val_dice_coef: 0.7360
#
# Epoch 00072: val_loss did not improve from 0.12759
# Epoch 73/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1367 - binary_accuracy: 0.9974 - iou: 0.7647 - dice_coef: 0.8636 - val_loss: 0.1666 - val_binary_accuracy: 0.9973 - val_iou: 0.7221 - val_dice_coef: 0.8358
#
# Epoch 00073: val_loss did not improve from 0.12759
# Epoch 74/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1298 - binary_accuracy: 0.9976 - iou: 0.7765 - dice_coef: 0.8701 - val_loss: 0.1402 - val_binary_accuracy: 0.9975 - val_iou: 0.7670 - val_dice_coef: 0.8645
#
# Epoch 00074: val_loss did not improve from 0.12759
# Epoch 75/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.9223 - binary_accuracy: 0.9739 - iou: 0.0433 - dice_coef: 0.0773 - val_loss: 0.6416 - val_binary_accuracy: 0.9673 - val_iou: 0.2145 - val_dice_coef: 0.3452
#
# Epoch 00075: val_loss did not improve from 0.12759
# Epoch 76/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1542 - binary_accuracy: 0.9958 - iou: 0.7485 - dice_coef: 0.8463 - val_loss: 0.1452 - val_binary_accuracy: 0.9974 - val_iou: 0.7553 - val_dice_coef: 0.8586
#
# Epoch 00076: val_loss did not improve from 0.12759
# Epoch 77/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1175 - binary_accuracy: 0.9977 - iou: 0.7935 - dice_coef: 0.8823 - val_loss: 0.1371 - val_binary_accuracy: 0.9975 - val_iou: 0.7645 - val_dice_coef: 0.8641
#
# Epoch 00077: val_loss did not improve from 0.12759
# Epoch 78/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1261 - binary_accuracy: 0.9976 - iou: 0.7775 - dice_coef: 0.8681 - val_loss: 0.2154 - val_binary_accuracy: 0.9967 - val_iou: 0.6323 - val_dice_coef: 0.7572
#
# Epoch 00078: val_loss did not improve from 0.12759
# Epoch 79/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1223 - binary_accuracy: 0.9977 - iou: 0.7836 - dice_coef: 0.8720 - val_loss: 0.1526 - val_binary_accuracy: 0.9975 - val_iou: 0.7504 - val_dice_coef: 0.8521
#
# Epoch 00079: val_loss did not improve from 0.12759
# Epoch 80/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1258 - binary_accuracy: 0.9976 - iou: 0.7842 - dice_coef: 0.8745 - val_loss: 0.1242 - val_binary_accuracy: 0.9977 - val_iou: 0.7805 - val_dice_coef: 0.8751
#
# Epoch 00080: val_loss improved from 0.12759 to 0.12423, saving model to unet_membrane.hdf5
# Epoch 81/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1166 - binary_accuracy: 0.9977 - iou: 0.7957 - dice_coef: 0.8833 - val_loss: 0.1315 - val_binary_accuracy: 0.9977 - val_iou: 0.7809 - val_dice_coef: 0.8730
#
# Epoch 00081: val_loss did not improve from 0.12423
# Epoch 82/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1237 - binary_accuracy: 0.9976 - iou: 0.7851 - dice_coef: 0.8769 - val_loss: 0.1176 - val_binary_accuracy: 0.9977 - val_iou: 0.7823 - val_dice_coef: 0.8753
#
# Epoch 00082: val_loss improved from 0.12423 to 0.11763, saving model to unet_membrane.hdf5
# Epoch 83/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1145 - binary_accuracy: 0.9976 - iou: 0.7990 - dice_coef: 0.8852 - val_loss: 0.1539 - val_binary_accuracy: 0.9972 - val_iou: 0.7300 - val_dice_coef: 0.8395
#
# Epoch 00083: val_loss did not improve from 0.11763
# Epoch 84/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1231 - binary_accuracy: 0.9976 - iou: 0.7886 - dice_coef: 0.8769 - val_loss: 0.1143 - val_binary_accuracy: 0.9981 - val_iou: 0.7927 - val_dice_coef: 0.8823
#
# Epoch 00084: val_loss improved from 0.11763 to 0.11429, saving model to unet_membrane.hdf5
# Epoch 85/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1217 - binary_accuracy: 0.9977 - iou: 0.7884 - dice_coef: 0.8787 - val_loss: 0.1729 - val_binary_accuracy: 0.9963 - val_iou: 0.7163 - val_dice_coef: 0.8317
#
# Epoch 00085: val_loss did not improve from 0.11429
# Epoch 86/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1310 - binary_accuracy: 0.9974 - iou: 0.7756 - dice_coef: 0.8683 - val_loss: 0.1596 - val_binary_accuracy: 0.9974 - val_iou: 0.7296 - val_dice_coef: 0.8413
#
# Epoch 00086: val_loss did not improve from 0.11429
# Epoch 87/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1218 - binary_accuracy: 0.9978 - iou: 0.7915 - dice_coef: 0.8783 - val_loss: 0.1154 - val_binary_accuracy: 0.9978 - val_iou: 0.8026 - val_dice_coef: 0.8876
#
# Epoch 00087: val_loss did not improve from 0.11429
# Epoch 88/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1137 - binary_accuracy: 0.9978 - iou: 0.8009 - dice_coef: 0.8863 - val_loss: 0.1976 - val_binary_accuracy: 0.9968 - val_iou: 0.6792 - val_dice_coef: 0.8043
#
# Epoch 00088: val_loss did not improve from 0.11429
# Epoch 89/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1251 - binary_accuracy: 0.9976 - iou: 0.7826 - dice_coef: 0.8750 - val_loss: 0.1225 - val_binary_accuracy: 0.9977 - val_iou: 0.7826 - val_dice_coef: 0.8762
#
# Epoch 00089: val_loss did not improve from 0.11429
# Epoch 90/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1126 - binary_accuracy: 0.9978 - iou: 0.8019 - dice_coef: 0.8873 - val_loss: 0.1232 - val_binary_accuracy: 0.9977 - val_iou: 0.7845 - val_dice_coef: 0.8769
#
# Epoch 00090: val_loss did not improve from 0.11429
# Epoch 91/100
# 66/88 [=====================>........] - ETA: 23s - loss: 0.1198 - binary_accuracy: 0.9978 - iou: 0.7947 - dice_coef: 0.8802

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Save Model</h3> <a id=5.4></a>

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model.h5')

# %%
# saving model achitecture in json file
model_json = model.to_json()
with open("UNet-seg-model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Evaluation</h3> <a id=6></a>
#
# Evaluation metrics are listed below

# %%
history.history.keys()

# %% [markdown]
# **Loss function** :  IOU - Intersection over Union

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);
plt.title("Segmentation Model IOU Loss");
plt.ylabel("IOU loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %% [markdown]
# <h3 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Prediction</h3> <a id=7></a>

# %%
test_ids = list(mri_test.img_path)
test_mask = list(mri_test.mask_path)

# %%
def prediction(test, model_seg):
  
    # empty list to store results
    mask, image_id,has_mask = [], [], []
    
    #itetrating through each image in test data
    for i in test.img_path:
        

        
        #Creating a empty array of shape 1,256,256,1
        X = np.empty((1,256,256,3))
        # read the image
        img = io.imread(i)
        #resizing the image and coverting them to array of type float64
        img = cv2.resize(img, (256,256))
        img = np.array(img, dtype=np.float64)
        
        # standardising the image
        img -= img.mean()
        img /= img.std()
        #converting the shape of image from 256,256,3 to 1,256,256,3
        X[0,] = img
        
        #make prediction of mask
        predict = model_seg.predict(X)
        
        # if sum of predicted mask is 0 then there is not tumour
        if predict.round().astype(int).sum()==0:
            image_id.append(i)
            has_mask.append(0)
            mask.append('No mask :)')
        else:
        #if the sum of pixel values are more than 0, then there is tumour
            image_id.append(i)
            has_mask.append(1)
            mask.append(predict)
            
    return pd.DataFrame({'img_path': image_id,'predicted_mask': mask,'has_mask': has_mask})

# %%
df_pred = prediction(mri_test, model)
df_pred

# %%
df_pred = mri_test.merge(df_pred, on='img_path')
df_pred.head()

# %%
count = 0
fig, axs = plt.subplots(3,3, figsize=(30,70))

for i in range(len(df_pred)):
    if df_pred.has_mask[i]==1 and count<15:
        #read mri images
        img = io.imread(df_pred.img_path[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        axs[count][0].imshow(img)
        axs[count][0].title.set_text('Brain MRI')
        
        #read original mask
        mask = io.imread(df_pred.mask_path[i])
        axs[count][1].imshow(mask)
        axs[count][1].title.set_text('Original Mask')
        
        #read predicted mask
        pred = np.array(df_pred.predicted_mask[i]).squeeze().round()
        axs[count][2].imshow(pred)
        axs[count][2].title.set_text('AI predicted mask')
        
        #overlay original mask with MRI
        img[mask==255] = (255,0,0)
        axs[count][3].imshow(img)
        axs[count][3].title.set_text('Brain MRI with original mask (Ground Truth)')
        
        #overlay predicted mask and MRI
        img_ = io.imread(df_pred.img_path[i])
        img_ = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
        img_[pred==1] = (0,255,150)
        axs[count][4].imshow(img_)
        axs[count][4].title.set_text('MRI with AI PREDICTED MASK')
        
        count +=1
    if (count==9):
        break

fig.tight_layout()

# %% [markdown]
# References:
# https://www.kaggle.com/code/minsi99/minsi-image-segmentation-trial-2
#
# https://www.kaggle.com/code/samuelcortinhas/case-study-u-net-from-scratch#Application:-Tumor-detection
